# %%
import pandas as pd
import numpy as np
import pymongo
df=pd.read_excel("data.xlsx")

# %%
df["salary"] = np.where(
    df["salary_rate"] == "year",
    df["salary_year_avg"],
    df["salary_hour_avg"] * 2080
)

# %%
df.drop(columns=["salary_rate","salary_year_avg","salary_hour_avg"], inplace=True)

# %%
df.head()
# Out:
#         job_title_short                               job_title  \
# 0        Data Scientist  Data Scientist, Data Platform Sciences
# 1        Data Scientist                     Lead Data Scientist
# 2  Senior Data Engineer                    Senior Data Engineer
# 3  Senior Data Engineer                    Senior Data Engineer
# 4          Data Analyst                   Data Analyst (Cyprus)
#
#         job_location    job_country          job_via        job_schedule_type  \
# 0  San Francisco, CA  United States     via Snagajob  Full-time and Part-time
# 1  San Francisco, CA  United States  via IT JobServe                Full-time
# 2  San Francisco, CA  United States     via LinkedIn                Full-time
# 3  San Francisco, CA  United States     via LinkedIn                Full-time
# 4   Limassol, Cyprus         Cyprus  via Ai-Jobs.net                Full-time
#
#    job_work_from_home            search_location     job_posted_date  \
# 0               False  California, United States 2023-11-01 18:02:42
# 1               False  California, United States 2023-04-14 20:03:13
# 2               False       Texas, United States 2023-12-08 11:06:48
# 3               False    Illinois, United States 2023-11-18 11:06:10
# 4               False                     Cyprus 2023-04-13 13:42:27
#
#    job_no_degree_mention  job_health_insurance company_name  \
# 0                  False                 False    Pinterest
# 1                  False                 False      Navient
# 2                   True                  True        Jobot
# 3                  False                  True        Jobot
# 4                   True                 False  capital.com
#
#                                           job_skills         salary
# 0                                 ['airflow', 'git']  111040.804443
# 1                   ['airflow', 'looker', 'tableau']  215049.000000
# 2  ['airflow', 'pyspark', 'pandas', 'looker', 'git']  225000.000000
# 3  ['airflow', 'pyspark', 'pandas', 'looker', 'git']  225000.000000
# 4          ['airflow', 'tableau', 'power bi', 'git']  102500.000000

# %%
df.isnull().sum()
# Out:
# job_title_short            0
# job_title                  0
# job_location              55
# job_country                0
# job_via                   10
# job_schedule_type        123
# job_work_from_home         0
# search_location            0
# job_posted_date            0
# job_no_degree_mention      0
# job_health_insurance       0
# company_name               0
# job_skills                 0
# salary                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29485 entries, 0 to 29484
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        29485 non-null  object
#  1   job_title              29485 non-null  object
#  2   job_location           29430 non-null  object
#  3   job_country            29485 non-null  object
#  4   job_via                29475 non-null  object
#  5   job_schedule_type      29362 non-null  object
#  6   job_work_from_home     29485 non-null  bool
#  7   search_location        29485 non-null  object
#  8   job_posted_date        29485 non-null  datetime64[ns]
#  9   job_no_degree_mention  29485 non-null  bool
#  10  job_health_insurance   29485 non-null  bool
#  11  company_name           29485 non-null  object
#  12  job_skills             29485 non-null  object
#  13  salary                 29485 non-null  float64
